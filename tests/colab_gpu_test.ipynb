# %%
# !pip install git+https://github.com/tyleryep/torchinfo
# !pip install ipytest
# !pip install transformers
# !pip install compressai
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
#   Cloning https://github.com/tyleryep/torchinfo to /tmp/pip-req-build-257pt9ut
#   Running command git clone --filter=blob:none --quiet https://github.com/tyleryep/torchinfo /tmp/pip-req-build-257pt9ut
#   Resolved https://github.com/tyleryep/torchinfo to commit a52edca1de606f939171426cf689a86531c9d9fd
#   Preparing metadata (setup.py) ... done
# ...
#   Created wheel for torchinfo: filename=torchinfo-1.7.2-py3-none-any.whl size=23321 sha256=775f5f28867beb2bb6385243f21ed818407cab7b29410e867c29ac76bf5c2930
#   Stored in directory: /tmp/pip-ephem-wheel-cache-rwz6xedc/wheels/57/64/22/ce519cb049aac5933bcd2a02ee72e71503ee3fb7319a3ac6f9
# Successfully built torchinfo
# ...
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 317.2/317.2 KB 14.2 MB/s eta 0:00:00
# ...

# %%
# Upload a .zip containing both torchinfo/ and tests/
# !unzip Archive.zip
# !rm -rf __MACOSX

# %%
# Run Pytest
# !pytest --durations=0
# Out:
# ============================= test session starts ==============================
# platform linux -- Python 3.9.16, pytest-7.2.2, pluggy-1.0.0 -- /usr/bin/python3
# cachedir: .pytest_cache
# rootdir: /content
# collected 85 items
#
# tests/exceptions_test.py::test_invalid_user_params PASSED                [  1%]
# tests/exceptions_test.py::test_incorrect_model_forward PASSED            [  2%]
# tests/exceptions_test.py::test_input_size_possible_exceptions PASSED     [  3%]
# tests/exceptions_test.py::test_forward_pass_exception PASSED             [  4%]
# tests/gpu_test.py::TestGPU::test_single_layer_network_on_gpu PASSED      [  5%]
# tests/gpu_test.py::TestGPU::test_single_layer_network_on_gpu_device PASSED [  7%]
# tests/gpu_test.py::TestGPU::test_input_size_half_precision PASSED        [  8%]
# tests/gpu_test.py::TestGPU::test_device PASSED                           [  9%]
# ...
